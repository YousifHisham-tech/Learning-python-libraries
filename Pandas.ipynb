# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_excel(r"C:\Users\elkha\Downloads\Benha University - All Faculities.xlsx", names=['Identity Code', 'Name', 'Faculty in benha'], sheet_name='Sheet1')
df2
# Out:
#       Identity Code                                         Name  \
# 0                 1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                 2              Samar Abdalaziz Ahmed Eltarawy
# 2                 4                    Ahmed Elsayed Gouda Attia
# 3                 5                           Zeyad Osama Farag
# 4                 6                    Asmaa Ibrahim Nabih Salah
# ...             ...                                          ...
# 2755           2749         Khaled Elsayed Abdelmaaboud Elsayed
# 2756           2750           Rana Ahmed Mohamed Mohamed Hassan
# 2757           2934                 Malak Hany Ebrahim El Saudi
# 2758           3005                  Fatma Mohammed Mahmoud Qamr
# 2759           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                     Faculty in benha
# 0             Faculty of Agriculture
# 1             Faculty of Agriculture
# 2             Faculty of Agriculture
# 3             Faculty of Agriculture
# ...

# %%
df2['Faculty in benha'].unique()
# Out:
# array(['Faculty of Agriculture', 'Faculty of Applied Arts',
#        'Faculty of Arts', 'Faculty of Commerce',
#        'Faculty of Computer and Artificial Intelligence',
#        'Faculty of Education', 'Faculty of Engineering (Benha)',
#        'Faculty of Engineering (Shoubra)', 'Faculty of Law',
#        'Faculty of Medicine', 'Faculty of Nursing',
#        'Faculty of Physical Education', 'Faculty of Physical Therapy',
#        'Faculty of Science', 'Faculty of Specific Education',
#        'Faculty of Veterinary Medicine'], dtype=object)

# %%
df2[1:11]
# Out:
#     Identity Code                             Name        Faculty in benha
# 1               2  Samar Abdalaziz Ahmed Eltarawy   Faculty of Agriculture
# 2               4        Ahmed Elsayed Gouda Attia  Faculty of Agriculture
# 3               5               Zeyad Osama Farag   Faculty of Agriculture
# 4               6        Asmaa Ibrahim Nabih Salah  Faculty of Agriculture
# 5               7    Mohammed Naser Mohammed Eraky  Faculty of Agriculture
# 6               8                Salma Ehab Qamar   Faculty of Agriculture
# 7               9      Sayed Khaled Elsayed Hassan  Faculty of Agriculture
# 8              10         Karim Mohamed Mousa  Eid  Faculty of Agriculture
# 9              11      Mohammad Gamal Araby Heraiz  Faculty of Agriculture
# 10             12              Fatima desoky amer   Faculty of Agriculture

# %%
#for displaying all the rows
pd.set_option('display.max.rows', 100)

# %%
df2
# Out:
#       Identity Code                                         Name  \
# 0                 1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                 2              Samar Abdalaziz Ahmed Eltarawy
# 2                 4                    Ahmed Elsayed Gouda Attia
# 3                 5                           Zeyad Osama Farag
# 4                 6                    Asmaa Ibrahim Nabih Salah
# ...             ...                                          ...
# 2755           2749         Khaled Elsayed Abdelmaaboud Elsayed
# 2756           2750           Rana Ahmed Mohamed Mohamed Hassan
# 2757           2934                 Malak Hany Ebrahim El Saudi
# 2758           3005                  Fatma Mohammed Mahmoud Qamr
# 2759           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                     Faculty in benha
# 0             Faculty of Agriculture
# 1             Faculty of Agriculture
# 2             Faculty of Agriculture
# 3             Faculty of Agriculture
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2760 entries, 0 to 2759
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Identity Code     2760 non-null   int64
#  1   Name              2760 non-null   object
#  2   Faculty in benha  2760 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 64.8+ KB

# %%
df2.head(10)
# Out:
#    Identity Code                                         Name  \
# 0              1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1              2              Samar Abdalaziz Ahmed Eltarawy
# 2              4                    Ahmed Elsayed Gouda Attia
# 3              5                           Zeyad Osama Farag
# 4              6                    Asmaa Ibrahim Nabih Salah
# 5              7                Mohammed Naser Mohammed Eraky
# 6              8                            Salma Ehab Qamar
# 7              9                  Sayed Khaled Elsayed Hassan
# 8             10                     Karim Mohamed Mousa  Eid
# 9             11                  Mohammad Gamal Araby Heraiz
#
#          Faculty in benha
# 0  Faculty of Agriculture
# 1  Faculty of Agriculture
# 2  Faculty of Agriculture
# 3  Faculty of Agriculture
# 4  Faculty of Agriculture
# 5  Faculty of Agriculture
# 6  Faculty of Agriculture
# 7  Faculty of Agriculture
# 8  Faculty of Agriculture
# ...

# %%
df2['Name']
# Out:
# 0       Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                   Samar Abdalaziz Ahmed Eltarawy
# 2                         Ahmed Elsayed Gouda Attia
# 3                                Zeyad Osama Farag
# 4                         Asmaa Ibrahim Nabih Salah
#                            ...
# 2755           Khaled Elsayed Abdelmaaboud Elsayed
# 2756             Rana Ahmed Mohamed Mohamed Hassan
# 2757                   Malak Hany Ebrahim El Saudi
# 2758                    Fatma Mohammed Mahmoud Qamr
# 2759          Aya_Tullah Bauomi Sayed Al_Fakharany
# Name: Name, Length: 2760, dtype: object

# %%
df2.loc[1100]
# Out:
# Identity Code                                                  1109
# Name                     Ahmed Elsayed Saber Elsayed Ali Elsharkawy
# Faculty in benha    Faculty of Computer and Artificial Intelligence
# Name: 1100, dtype: object

# %%
df2.iloc[1100]
# Out:
# Identity Code                                                  1109
# Name                     Ahmed Elsayed Saber Elsayed Ali Elsharkawy
# Faculty in benha    Faculty of Computer and Artificial Intelligence
# Name: 1100, dtype: object

# %%
df2[df2['Identity Code'] <= 250]
# Out:
#      Identity Code                                         Name  \
# 0                1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                2              Samar Abdalaziz Ahmed Eltarawy
# 2                4                    Ahmed Elsayed Gouda Attia
# 3                5                           Zeyad Osama Farag
# 4                6                    Asmaa Ibrahim Nabih Salah
# ..             ...                                          ...
# 209            244                   Menna Madian Abdellrahman
# 210            245                          Shahd sameh elsayed
# 211            247                                            R
# 212            248                 Manal Abdullah shaban salama
# 213            249                  Menna Abdullah Ismael Afifi
#
#            Faculty in benha
# 0    Faculty of Agriculture
# 1    Faculty of Agriculture
# 2    Faculty of Agriculture
# 3    Faculty of Agriculture
# 4    Faculty of Agriculture
# ...

# %%
df2[0:251]
# Out:
#      Identity Code                                         Name  \
# 0                1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                2              Samar Abdalaziz Ahmed Eltarawy
# 2                4                    Ahmed Elsayed Gouda Attia
# 3                5                           Zeyad Osama Farag
# 4                6                    Asmaa Ibrahim Nabih Salah
# ..             ...                                          ...
# 246            290               Roaa Mohamed Hemid Hamed Abeed
# 247            291          Alyaa Mousa Elsayed Mousa Aly Allam
# 248            292                       Marina Ayman Gad Fahmy
# 249            293                        Rewan Mostafa Elsayed
# 250            294                         Kholoud Ezzat Fathy
#
#            Faculty in benha
# 0    Faculty of Agriculture
# 1    Faculty of Agriculture
# 2    Faculty of Agriculture
# 3    Faculty of Agriculture
# 4    Faculty of Agriculture
# ...

# %%
s_facluties= ['Faculty of Computer and Artificial Intelligence', 'Faculty of Engineering (Benha)','Faculty of Engineering (Shoubra)']
df2[df2['Faculty in benha'].isin(s_facluties)]
# Out:
#       Identity Code                                               Name  \
# 728             687                               Ahmed Hazem Elabady
# 729             688                                   عبدالله طارق علي
# 730             689                          جنه اشرف محمد عبد الحميد
# 731             690       Mohammed Metwally Abouelnasr Metwally Salem
# 732             691                                   Mostafa Mahmoud
# ...             ...                                                ...
# 2053           2984                                       Manar Gafar
# 2054           2997                           Abdullah Yasser Abdullah
# 2055           3004                               Abdulrahman Eid Emam
# 2056           3045  Salah El-Din Saeed Ismail Abdel Aziz Ibrahim A...
# 2057           3111                                 Nourhan Nagy Mahdy
#
#                                      Faculty in benha
# 728   Faculty of Computer and Artificial Intelligence
# ...

# %%
df2[df2['Name'].str.contains('Yousif')]
# Out:
#       Identity Code                                Name  \
# 116             130             Yousif Mohamed Khalifa
# 878             842  Yousif Hisham Abdelfatah Abdelazim
# 1346           1390       Yousif Ibrahim Abd Almotalib
# 1368           1416          Yousif Osama Rashad Ahmed
# 1839           1843          Yousif Sherif Ahmed Shawky
# 2474           2453                Yousif Mohamed Saied
#
#                                      Faculty in benha
# 116                            Faculty of Agriculture
# 878   Faculty of Computer and Artificial Intelligence
# 1346  Faculty of Computer and Artificial Intelligence
# 1368  Faculty of Computer and Artificial Intelligence
# 1839                   Faculty of Engineering (Benha)
# 2474                               Faculty of Science

# %%
df3 = df2.set_index('Faculty in benha')
df3
# Out:
#                                 Identity Code  \
# Faculty in benha
# Faculty of Agriculture                      1
# Faculty of Agriculture                      2
# Faculty of Agriculture                      4
# Faculty of Agriculture                      5
# Faculty of Agriculture                      6
# ...                                       ...
# Faculty of Veterinary Medicine           2749
# Faculty of Veterinary Medicine           2750
# Faculty of Veterinary Medicine           2934
# Faculty of Veterinary Medicine           3005
# Faculty of Veterinary Medicine           3099
#
#                                                                        Name
# Faculty in benha
# Faculty of Agriculture          Radwa Abdelrazik Abdelwhab Salem Goma Wady
# Faculty of Agriculture                      Samar Abdalaziz Ahmed Eltarawy
# Faculty of Agriculture                            Ahmed Elsayed Gouda Attia
# ...

# %%
df3.filter(items=['Name'], axis=1)
# Out:
#                                                                        Name
# Faculty in benha
# Faculty of Agriculture          Radwa Abdelrazik Abdelwhab Salem Goma Wady
# Faculty of Agriculture                      Samar Abdalaziz Ahmed Eltarawy
# Faculty of Agriculture                            Ahmed Elsayed Gouda Attia
# Faculty of Agriculture                                   Zeyad Osama Farag
# Faculty of Agriculture                            Asmaa Ibrahim Nabih Salah
# ...                                                                     ...
# Faculty of Veterinary Medicine         Khaled Elsayed Abdelmaaboud Elsayed
# Faculty of Veterinary Medicine           Rana Ahmed Mohamed Mohamed Hassan
# Faculty of Veterinary Medicine                 Malak Hany Ebrahim El Saudi
# Faculty of Veterinary Medicine                  Fatma Mohammed Mahmoud Qamr
# Faculty of Veterinary Medicine        Aya_Tullah Bauomi Sayed Al_Fakharany
#
# [2760 rows x 1 columns]

# %%
df3.loc['Faculty of Agriculture']
# Out:
#                         Identity Code  \
# Faculty in benha
# Faculty of Agriculture              1
# Faculty of Agriculture              2
# Faculty of Agriculture              4
# Faculty of Agriculture              5
# Faculty of Agriculture              6
# ...                               ...
# Faculty of Agriculture           3087
# Faculty of Agriculture           3092
# Faculty of Agriculture           3094
# Faculty of Agriculture           3095
# Faculty of Agriculture           3097
#
#                                                                Name
# Faculty in benha
# Faculty of Agriculture  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# Faculty of Agriculture              Samar Abdalaziz Ahmed Eltarawy
# Faculty of Agriculture                    Ahmed Elsayed Gouda Attia
# Faculty of Agriculture                           Zeyad Osama Farag
# Faculty of Agriculture                    Asmaa Ibrahim Nabih Salah
# ...

# %%
iran = pd.read_csv(r"C:\Users\elkha\Downloads\iranian_national_id_card_data.csv")
iran
# Out:
#         id  national_id first_name last_name date_of_birth father_name  \
# 0        1   5116168397      مبینا      اسدی    1380/04/01      نریمان
# 1        2   5182864095      سمانه     خزایی    1385/08/04       یزدان
# 2        3   4813522511      شکوفه   میرزایی    1373/02/26      گرشاسب
# 3        4   7815520112      بنفشه    پورعلی    1384/02/20       سورنا
# 4        5   5665109964     گشتاسپ   علیزاده    1367/08/27       سهراب
# ...    ...          ...        ...       ...           ...         ...
# 1995  1996   1104184879       خسرو     آقایی    1377/04/14       آبتین
# 1996  1997   3865091369      یگانه     گلشنی    1366/11/01        سروش
# 1997  1998   2058831996       حشمت      زندی    1379/02/18     غلامرضا
# 1998  1999   8923759176       اکبر     پناهی    1378/09/09     غلامرضا
# 1999  2000   4682014169     مستانه    مردانی    1377/02/02      پارمیس
#
#      expiry_date
# 0     1409/10/19
# 1     1414/11/23
# 2     1412/12/29
# 3     1412/08/08
# 4     1410/03/03
# ...

# %%
#pd.set_option('display.max.rows', 2000)
#iran
df3.filter(like='100', axis=1)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
iran.sort_values(by='expiry_date', ascending=True)
# Out:
#         id  national_id first_name last_name date_of_birth father_name  \
# 1399  1400   5729709267      سمانه     واحدی    1379/11/27       سورنا
# 1291  1292   3298156366    زرافشان      زندی    1380/01/19        هژیر
# 7        8   9794376184      بهرام      زرگر    1369/09/06       بهزاد
# 916    917   7411234656      روژین     خالقی    1363/08/12       مانوش
# 353    354   2989970254      شاهین   عابدینی    1368/01/21       پرویز
# ...    ...          ...        ...       ...           ...         ...
# 1725  1726   6531620471     اردلان  میرباقری    1372/08/23       یاسین
# 334    335   1391816129     شهرزاد     کریمی    1369/02/13       فرشاد
# 133    134   3503227322       یغما     کارگر    1379/11/19       مهران
# 1075  1076   3125995413      فیروز     کیانی    1383/05/09       آرمین
# 1951  1952   7831690012      نیایش      ندوی    1373/07/17       یارتا
#
#      expiry_date
# 1399  1405/01/01
# 1291  1405/01/03
# 7     1405/01/12
# 916   1405/01/12
# 353   1405/01/13
# ...

# %%
iran.set_index('national_id', inplace=True)
iran
# Out:
#                id first_name last_name date_of_birth father_name expiry_date
# national_id
# 5116168397      1      مبینا      اسدی    1380/04/01      نریمان  1409/10/19
# 5182864095      2      سمانه     خزایی    1385/08/04       یزدان  1414/11/23
# 4813522511      3      شکوفه   میرزایی    1373/02/26      گرشاسب  1412/12/29
# 7815520112      4      بنفشه    پورعلی    1384/02/20       سورنا  1412/08/08
# 5665109964      5     گشتاسپ   علیزاده    1367/08/27       سهراب  1410/03/03
# ...           ...        ...       ...           ...         ...         ...
# 1104184879   1996       خسرو     آقایی    1377/04/14       آبتین  1413/11/25
# 3865091369   1997      یگانه     گلشنی    1366/11/01        سروش  1414/11/26
# 2058831996   1998       حشمت      زندی    1379/02/18     غلامرضا  1409/10/15
# 8923759176   1999       اکبر     پناهی    1378/09/09     غلامرضا  1409/06/08
# 4682014169   2000     مستانه    مردانی    1377/02/02      پارمیس  1405/05/15
#
# [2000 rows x 6 columns]

# %%
iran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 5116168397 to 4682014169
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2000 non-null   int64
#  1   first_name     2000 non-null   object
#  2   last_name      2000 non-null   object
#  3   date_of_birth  2000 non-null   object
#  4   father_name    2000 non-null   object
#  5   expiry_date    2000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 109.4+ KB

# %%
iran.loc[5116168397]
# Out:
# id                        1
# first_name            مبینا
# last_name              اسدی
# date_of_birth    1380/04/01
# father_name          نریمان
# expiry_date      1409/10/19
# Name: 5116168397, dtype: object

# %%
iran.iloc[0]
# Out:
# id                        1
# first_name            مبینا
# last_name              اسدی
# date_of_birth    1380/04/01
# father_name          نریمان
# expiry_date      1409/10/19
# Name: 5116168397, dtype: object

# %%
iran.sort_index(ascending=True, inplace=True)
iran
# Out:
#                id first_name last_name date_of_birth father_name expiry_date
# national_id
# 1007303834   1421     یزدگرد     تاجیک    1367/10/07        آرتا  1412/07/17
# 1010185186    855       محیا    منصوری    1383/03/26       مسعود  1407/02/22
# 1016220363    951     ارغوان    اقبالی    1362/11/16        جمال  1409/06/26
# 1037728306   1588       دنیا      زرین    1384/12/10        رحیم  1408/08/17
# 1043845431    830       قاسم     مقیمی    1381/02/13       پدرام  1407/07/13
# ...           ...        ...       ...           ...         ...         ...
# 9968260942   1366      مجتبی   عابدینی    1381/10/28        ناصر  1408/11/26
# 9990480498    403    ابراهیم     شریفی    1382/04/08        نیما  1414/12/02
# 9993596498   1703      بردیا     فقیهی    1374/01/23     محمدرضا  1406/04/01
# 9996376998   1980      خدیجه  میرحسینی    1370/02/03    محمدمهدی  1413/02/20
# 9999482410    670      سیامک    ادریسی    1380/06/24        سروش  1411/03/18
#
# [2000 rows x 6 columns]

# %%
df3.drop(columns=['Name'], inplace=True)
count = df3.groupby('Faculty in benha')
count.mean()
# Out:
#                                                  Identity Code
# Faculty in benha
# Faculty of Agriculture                              638.600000
# Faculty of Applied Arts                             491.235294
# Faculty of Arts                                     732.619048
# Faculty of Commerce                                 888.174648
# Faculty of Computer and Artificial Intelligence    1359.507583
# Faculty of Education                               1854.351351
# Faculty of Engineering (Benha)                     1912.808917
# Faculty of Engineering (Shoubra)                   2101.040816
# Faculty of Law                                     2338.078261
# Faculty of Medicine                                2133.500000
# Faculty of Nursing                                 2137.000000
# Faculty of Physical Education                      2206.740741
# Faculty of Physical Therapy                        2168.625000
# Faculty of Science                                 2446.184959
# ...

# %%
count.count()
# Out:
#                                                  Identity Code
# Faculty in benha
# Faculty of Agriculture                                     335
# Faculty of Applied Arts                                     17
# Faculty of Arts                                             21
# Faculty of Commerce                                        355
# Faculty of Computer and Artificial Intelligence            989
# Faculty of Education                                        37
# Faculty of Engineering (Benha)                             157
# Faculty of Engineering (Shoubra)                           147
# Faculty of Law                                             115
# Faculty of Medicine                                          2
# Faculty of Nursing                                           5
# Faculty of Physical Education                               27
# Faculty of Physical Therapy                                  8
# Faculty of Science                                         492
# ...

# %%
count.min()
# Out:
#                                                  Identity Code
# Faculty in benha
# Faculty of Agriculture                                       1
# Faculty of Applied Arts                                    327
# Faculty of Arts                                            346
# Faculty of Commerce                                        365
# Faculty of Computer and Artificial Intelligence            687
# Faculty of Education                                      1700
# Faculty of Engineering (Benha)                            1737
# Faculty of Engineering (Shoubra)                          1906
# Faculty of Law                                            2045
# Faculty of Medicine                                       2133
# Faculty of Nursing                                        2135
# Faculty of Physical Education                             2140
# Faculty of Physical Therapy                               2165
# Faculty of Science                                        2174
# ...

# %%
count.max()
# Out:
#                                                  Identity Code
# Faculty in benha
# Faculty of Agriculture                                    3097
# Faculty of Applied Arts                                   2994
# Faculty of Arts                                           3107
# Faculty of Commerce                                       3088
# Faculty of Computer and Artificial Intelligence           3115
# Faculty of Education                                      3060
# Faculty of Engineering (Benha)                            3083
# Faculty of Engineering (Shoubra)                          3111
# Faculty of Law                                            3078
# Faculty of Medicine                                       2134
# Faculty of Nursing                                        2139
# Faculty of Physical Education                             3006
# Faculty of Physical Therapy                               2173
# Faculty of Science                                        3096
# ...

# %%
df3.max()
# Out:
# Identity Code    3115
# dtype: int64

# %%
count.sum()
# Out:
#                                                  Identity Code
# Faculty in benha
# Faculty of Agriculture                                  213931
# Faculty of Applied Arts                                   8351
# Faculty of Arts                                          15385
# Faculty of Commerce                                     315302
# Faculty of Computer and Artificial Intelligence        1344553
# Faculty of Education                                     68611
# Faculty of Engineering (Benha)                          300311
# Faculty of Engineering (Shoubra)                        308853
# Faculty of Law                                          268879
# Faculty of Medicine                                       4267
# Faculty of Nursing                                       10685
# Faculty of Physical Education                            59582
# Faculty of Physical Therapy                              17349
# Faculty of Science                                     1203523
# ...

# %%
count.agg({'Identity Code':['mean', 'min', 'max', 'count', 'sum', 'std']})
# Out:
#                                                 Identity Code              \
#                                                          mean   min   max
# Faculty in benha
# Faculty of Agriculture                             638.600000     1  3097
# Faculty of Applied Arts                            491.235294   327  2994
# Faculty of Arts                                    732.619048   346  3107
# Faculty of Commerce                                888.174648   365  3088
# Faculty of Computer and Artificial Intelligence   1359.507583   687  3115
# Faculty of Education                              1854.351351  1700  3060
# Faculty of Engineering (Benha)                    1912.808917  1737  3083
# Faculty of Engineering (Shoubra)                  2101.040816  1906  3111
# Faculty of Law                                    2338.078261  2045  3078
# Faculty of Medicine                               2133.500000  2133  2134
# ...

# %%
cars = pd.read_csv(r"C:\Users\elkha\Downloads\archive\used_car_price_dataset_extended.csv")
cars
# Out:
#       make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0          2001          8.17       4000    Petrol            4    8587.64
# 1          2014         17.59       1500    Petrol            4    5943.50
# 2          2023         18.09       2500    Diesel            5    9273.58
# 3          2009         11.28        800    Petrol            1    6836.24
# 4          2005         12.23       1000    Petrol            2    4625.79
# ...         ...           ...        ...       ...          ...        ...
# 9995       1996         15.25       1500    Petrol            2    5498.71
# 9996       1997         14.45       5000    Diesel            1    9588.31
# 9997       2002         19.41       1000    Diesel            4    4557.10
# 9998       2005         12.95       4000    Petrol            5    7413.59
# 9999       2007         18.81       5000    Petrol            1   11634.09
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   make_year           10000 non-null  int64
#  1   mileage_kmpl        10000 non-null  float64
#  2   engine_cc           10000 non-null  int64
#  3   fuel_type           10000 non-null  object
#  4   owner_count         10000 non-null  int64
#  5   price_usd           10000 non-null  float64
#  6   brand               10000 non-null  object
#  7   transmission        10000 non-null  object
#  8   color               10000 non-null  object
#  9   service_history     7962 non-null   object
#  10  accidents_reported  10000 non-null  int64
#  11  insurance_valid     10000 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 937.6+ KB

# %%
cars.groupby('fuel_type').count()
# Out:
#            make_year  mileage_kmpl  engine_cc  owner_count  price_usd  brand  \
# fuel_type
# Diesel          4058          4058       4058         4058       4058   4058
# Electric         974           974        974          974        974    974
# Petrol          4968          4968       4968         4968       4968   4968
#
#            transmission  color  service_history  accidents_reported  \
# fuel_type
# Diesel             4058   4058             3210                4058
# Electric            974    974              781                 974
# Petrol             4968   4968             3971                4968
#
#            insurance_valid
# fuel_type
# Diesel                4058
# Electric               974
# Petrol                4968

# %%
cars.groupby('fuel_type').agg({'make_year': ['mean', 'max', 'min', 'std', 'count', 'sum']})
# Out:
#              make_year
#                   mean   max   min       std count      sum
# fuel_type
# Diesel     2009.129867  2023  1995  8.438158  4058  8153049
# Electric   2008.866530  2023  1995  8.363937   974  1956636
# Petrol     2009.336554  2023  1995  8.321955  4968  9982384

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   make_year           10000 non-null  int64
#  1   mileage_kmpl        10000 non-null  float64
#  2   engine_cc           10000 non-null  int64
#  3   fuel_type           10000 non-null  object
#  4   owner_count         10000 non-null  int64
#  5   price_usd           10000 non-null  float64
#  6   brand               10000 non-null  object
#  7   transmission        10000 non-null  object
#  8   color               10000 non-null  object
#  9   service_history     7962 non-null   object
#  10  accidents_reported  10000 non-null  int64
#  11  insurance_valid     10000 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 937.6+ KB

# %%
cars.groupby(['brand', 'transmission','fuel_type']).count()
# Out:
#                                    make_year  mileage_kmpl  engine_cc  \
# brand      transmission fuel_type
# BMW        Automatic    Diesel           154           154        154
#                         Electric          40            40         40
#                         Petrol           191           191        191
#            Manual       Diesel           273           273        273
#                         Electric          64            64         64
#                         Petrol           299           299        299
# Chevrolet  Automatic    Diesel           167           167        167
#                         Electric          34            34         34
#                         Petrol           209           209        209
#            Manual       Diesel           232           232        232
#                         Electric          59            59         59
#                         Petrol           298           298        298
# ...

# %%
pd.set_option('display.max.columns', 100)
pd.set_option('display.max.rows', 100)

# %%
cars.groupby(['brand', 'transmission','fuel_type']).describe()
# Out:
#                                   make_year                                 \
#                                       count         mean       std     min
# brand      transmission fuel_type
# BMW        Automatic    Diesel        154.0  2009.909091  8.113866  1995.0
#                         Electric       40.0  2007.875000  7.225977  1995.0
#                         Petrol        191.0  2009.759162  7.696521  1995.0
#            Manual       Diesel        273.0  2009.025641  8.189129  1995.0
#                         Electric       64.0  2006.515625  8.853288  1995.0
#                         Petrol        299.0  2009.705686  8.739346  1995.0
# Chevrolet  Automatic    Diesel        167.0  2009.113772  8.213579  1995.0
#                         Electric       34.0  2006.088235  8.497300  1995.0
#                         Petrol        209.0  2010.272727  7.954635  1995.0
#            Manual       Diesel        232.0  2009.857759  8.433161  1995.0
# ...

# %%
df2.set_index('Identity Code', inplace=True)
df2
# Out:
#                                                       Name  \
# Identity Code
# 1              Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 2                          Samar Abdalaziz Ahmed Eltarawy
# 4                                Ahmed Elsayed Gouda Attia
# 5                                       Zeyad Osama Farag
# 6                                Asmaa Ibrahim Nabih Salah
# ...                                                    ...
# 2749                  Khaled Elsayed Abdelmaaboud Elsayed
# 2750                    Rana Ahmed Mohamed Mohamed Hassan
# 2934                          Malak Hany Ebrahim El Saudi
# 3005                           Fatma Mohammed Mahmoud Qamr
# 3099                 Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                              Faculty in benha
# Identity Code
# 1                      Faculty of Agriculture
# 2                      Faculty of Agriculture
# 4                      Faculty of Agriculture
# ...

# %%
df2.loc[4]
# Out:
# Name                Ahmed Elsayed Gouda Attia
# Faculty in benha       Faculty of Agriculture
# Name: 4, dtype: object

# %%
df4 = pd.read_excel(r"C:\Users\elkha\Downloads\Benha University - All Faculities.xlsx", names=['Identity Code', 'Name', 'Faculty in benha'], sheet_name='Sheet1')
df4.merge(df2, how='cross')
# Out:
#          Identity Code                                       Name_x  \
# 0                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 2                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 3                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 4                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# ...                ...                                          ...
# 7617595           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617596           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617597           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617598           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617599           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                      Faculty in benha_x  \
# 0                Faculty of Agriculture
# 1                Faculty of Agriculture
# ...

# %%
df2.sort_values('Faculty in benha', ascending=False, inplace=True)
df4.merge(df2, how='cross')
# Out:
#          Identity Code                                       Name_x  \
# 0                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 2                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 3                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 4                    1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# ...                ...                                          ...
# 7617595           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617596           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617597           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617598           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
# 7617599           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                      Faculty in benha_x  \
# 0                Faculty of Agriculture
# 1                Faculty of Agriculture
# ...

# %%
#pd.set_option("display.max.rows",3000)
df4
# Out:
#       Identity Code                                         Name  \
# 0                 1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                 2              Samar Abdalaziz Ahmed Eltarawy
# 2                 4                    Ahmed Elsayed Gouda Attia
# 3                 5                           Zeyad Osama Farag
# 4                 6                    Asmaa Ibrahim Nabih Salah
# ...             ...                                          ...
# 2755           2749         Khaled Elsayed Abdelmaaboud Elsayed
# 2756           2750           Rana Ahmed Mohamed Mohamed Hassan
# 2757           2934                 Malak Hany Ebrahim El Saudi
# 2758           3005                  Fatma Mohammed Mahmoud Qamr
# 2759           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                     Faculty in benha
# 0             Faculty of Agriculture
# 1             Faculty of Agriculture
# 2             Faculty of Agriculture
# 3             Faculty of Agriculture
# ...

# %%
df4.set_index('Name', inplace=True)
df2.set_index('Name', inplace=True)
df5 = df4.join(df2, how='outer', on='Name', lsuffix='_left', rsuffix='_right')
df5.columns = ['Identity Code', 'left', 'right']
df5
# Out:
#                                            Identity Code  \
# Name
#   Adham Ashraf Mohammed Ali                         1699
#   Marina Micheel Yani Mina Hana                      648
#   Mohamed kamel Gmail marwan                        1116
#   Mostafa Magdy Said  Mohamed                         14
#   Sara Helmy SHaaban Abdel Halim El Degwy            106
# ...                                                  ...
# يوسف عبد الشافي احمد يوسف                            870
# يوسف محمد رمضان حسين                                 573
# يوسف منصور محمد محمد                                2286
# يوسف ياسر سيد محمود                                 2010
# ِApdulrahman Mahmoud Shabaan                        1025
#
#                                                                                       left  \
# Name
#   Adham Ashraf Mohammed Ali                Faculty of Computer and Artificial Intelligence
# ...

# %%
df5[~(df5['left'] == df5['right'])]
# Out:
# Empty DataFrame
# Columns: [Name, Identity Code, left, right]
# Index: []

# %%
df5.loc['Yousif Hisham Abdelfatah Abdelazim']
# Out:
# Identity Code                                                842
# left             Faculty of Computer and Artificial Intelligence
# right            Faculty of Computer and Artificial Intelligence
# Name: Yousif Hisham Abdelfatah Abdelazim, dtype: object

# %%
df5.reset_index(inplace=True)
temp = df5[df5['Name'].str.contains('Hesham')]
pd.concat([temp, df5], ignore_index=False)
# Out:
#       level_0  index                                    Name  Identity Code  \
# 507       507    507                       Anas Hesham Ahmed            121
# 663       663    663                   Doha Hesham Hassanin            1786
# 1099     1099   1099                      Mahetap Hesham Aly            355
# 1125     1125   1125  Mahmoud Hesham Mahmoud Mohamed Elberry           1675
# 1309     1309   1309            Maryam Mohamed Hesham Elziky           1915
# ...       ...    ...                                     ...            ...
# 2755     2755   2755              يوسف عبد الشافي احمد يوسف             870
# 2756     2756   2756                   يوسف محمد رمضان حسين             573
# 2757     2757   2757                   يوسف منصور محمد محمد            2286
# 2758     2758   2758                    يوسف ياسر سيد محمود            2010
# 2759     2759   2759            ِApdulrahman Mahmoud Shabaan           1025
#
#                                                  left  \
# ...

# %%
pd.concat([df5[df5['Name'].str.contains('Hisham')], temp, df5[df5['Name'].str.contains('hisham')], df5[df5['Name'].str.contains('hesham')], df5[df5['Name'].str.contains('Amar')]], join='outer', axis = 1)
# Out:
#                                                Name  Identity Code  \
# 701                             Eman Hisham Ismail           765.0
# 757                             Essam Eldin Hisham          2012.0
# 1058              Khaled Hisham Ibrahim Ahmed Salem         1659.0
# 1341                    Menna Hisham Mohamed Attia           236.0
# 1361    Mennatallah Hisham Abdelsattar Ahmed Farrag          521.0
# 1753                           Noura Hisham Mohamed         2873.0
# 1792                                   Omar Hisham          1140.0
# 1793                       Omar Hisham Hassan Kamel          532.0
# 1941  Roaa Hisham Abdelmonem Abdelaziz Sharafeldin          1473.0
# 2149                           Shams  Hisham Sabry          1394.0
# 2235                        Wesal Hisham Abdelwahed         1257.0
# 2299             Yousif Hisham Abdelfatah Abdelazim          842.0
# 507                                             NaN            NaN
# ...

# %%
import pandas as pd
df = pd.DataFrame({
  'Color': ['Red', 'Green', 'Blue', 'Green']
})
pd.get_dummies(df)
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1       False         True      False
# 2        True        False      False
# 3       False         True      False

# %%
df
# Out:
#    Color
# 0    Red
# 1  Green
# 2   Blue
# 3  Green

# %%
pd.set_option('display.max.rows', 400)

# %%
df2
# Out:
#       Identity Code                                         Name  \
# 0                 1  Radwa Abdelrazik Abdelwhab Salem Goma Wady
# 1                 2              Samar Abdalaziz Ahmed Eltarawy
# 2                 4                    Ahmed Elsayed Gouda Attia
# 3                 5                           Zeyad Osama Farag
# 4                 6                    Asmaa Ibrahim Nabih Salah
# ...             ...                                          ...
# 2755           2749         Khaled Elsayed Abdelmaaboud Elsayed
# 2756           2750           Rana Ahmed Mohamed Mohamed Hassan
# 2757           2934                 Malak Hany Ebrahim El Saudi
# 2758           3005                  Fatma Mohammed Mahmoud Qamr
# 2759           3099        Aya_Tullah Bauomi Sayed Al_Fakharany
#
#                     Faculty in benha
# 0             Faculty of Agriculture
# 1             Faculty of Agriculture
# 2             Faculty of Agriculture
# 3             Faculty of Agriculture
# ...

# %% [markdown]
# # Performing one-hot encoding

# %%
df2 = pd.read_excel(r"C:\Users\elkha\Downloads\Benha University - All Faculities.xlsx", names=['Identity Code', 'Name', 'Faculty in benha'], sheet_name='Sheet1')
df = pd.get_dummies(df2['Faculty in benha'], drop_first=True)

# %%
df2['Faculty in benha'].unique()
# Out:
# array(['Faculty of Agriculture', 'Faculty of Applied Arts',
#        'Faculty of Arts', 'Faculty of Commerce',
#        'Faculty of Computer and Artificial Intelligence',
#        'Faculty of Education', 'Faculty of Engineering (Benha)',
#        'Faculty of Engineering (Shoubra)', 'Faculty of Law',
#        'Faculty of Medicine', 'Faculty of Nursing',
#        'Faculty of Physical Education', 'Faculty of Physical Therapy',
#        'Faculty of Science', 'Faculty of Specific Education',
#        'Faculty of Veterinary Medicine'], dtype=object)

# %%
df.shape
# Out:
# (2760, 15)

# %%
df
# Out:
#       Faculty of Applied Arts  Faculty of Arts  Faculty of Commerce  \
# 0                       False            False                False
# 1                       False            False                False
# 2                       False            False                False
# 3                       False            False                False
# 4                       False            False                False
# ...                       ...              ...                  ...
# 2755                    False            False                False
# 2756                    False            False                False
# 2757                    False            False                False
# 2758                    False            False                False
# 2759                    False            False                False
#
#       Faculty of Computer and Artificial Intelligence  Faculty of Education  \
# ...

# %%
df2['Faculty in benha'].value_counts().sort_values(ascending=False)
# Out:
# Faculty in benha
# Faculty of Computer and Artificial Intelligence    989
# Faculty of Science                                 492
# Faculty of Commerce                                355
# Faculty of Agriculture                             335
# Faculty of Engineering (Benha)                     157
# Faculty of Engineering (Shoubra)                   147
# Faculty of Law                                     115
# Faculty of Education                                37
# Faculty of Veterinary Medicine                      34
# Faculty of Physical Education                       27
# Faculty of Arts                                     21
# Faculty of Specific Education                       19
# Faculty of Applied Arts                             17
# Faculty of Physical Therapy                          8
# Faculty of Nursing                                   5
# Faculty of Medicine                                  2
# Name: count, dtype: int64

# %%
top_10 = [x for x in df2['Faculty in benha'].value_counts().sort_values(ascending=False).head(11).index]

# %%
top_10
# Out:
# ['Faculty of Computer and Artificial Intelligence',
#  'Faculty of Science',
#  'Faculty of Commerce',
#  'Faculty of Agriculture',
#  'Faculty of Engineering (Benha)',
#  'Faculty of Engineering (Shoubra)',
#  'Faculty of Law',
#  'Faculty of Education',
#  'Faculty of Veterinary Medicine',
#  'Faculty of Physical Education',
#  'Faculty of Arts']

# %%
df2['Faculty in benha']
# Out:
# 0               Faculty of Agriculture
# 1               Faculty of Agriculture
# 2               Faculty of Agriculture
# 3               Faculty of Agriculture
# 4               Faculty of Agriculture
#                      ...
# 2755    Faculty of Veterinary Medicine
# 2756    Faculty of Veterinary Medicine
# 2757    Faculty of Veterinary Medicine
# 2758    Faculty of Veterinary Medicine
# 2759    Faculty of Veterinary Medicine
# Name: Faculty in benha, Length: 2760, dtype: object
