# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv(r"C:\Users\elkha\Downloads\archive\used_car_price_dataset_extended.csv")
cars
# Out:
#       make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0          2001          8.17       4000    Petrol            4    8587.64
# 1          2014         17.59       1500    Petrol            4    5943.50
# 2          2023         18.09       2500    Diesel            5    9273.58
# 3          2009         11.28        800    Petrol            1    6836.24
# 4          2005         12.23       1000    Petrol            2    4625.79
# ...         ...           ...        ...       ...          ...        ...
# 9995       1996         15.25       1500    Petrol            2    5498.71
# 9996       1997         14.45       5000    Diesel            1    9588.31
# 9997       2002         19.41       1000    Diesel            4    4557.10
# 9998       2005         12.95       4000    Petrol            5    7413.59
# 9999       2007         18.81       5000    Petrol            1   11634.09
#
# ...

# %%
coll = pd.read_excel(r"C:\Users\elkha\Downloads\Benha University - All Faculities.xlsx")
coll.head()
# Out:
#    ID                                    Full Name                 Faculty
# 0   1  Radwa Abdelrazik Abdelwhab Salem Goma Wady   Faculty of Agriculture
# 1   2              Samar Abdalaziz Ahmed Eltarawy   Faculty of Agriculture
# 2   4                    Ahmed Elsayed Gouda Attia  Faculty of Agriculture
# 3   5                           Zeyad Osama Farag   Faculty of Agriculture
# 4   6                    Asmaa Ibrahim Nabih Salah  Faculty of Agriculture

# %%
cars.plot(kind='bar')
# Out:
# <Axes: >

# %%
cars.plot(kind='line')
# Out:
# <Axes: >

# %%
cars.plot(kind='bar', subplots=True)
# Out:
# array([<Axes: title={'center': 'make_year'}>,
#        <Axes: title={'center': 'mileage_kmpl'}>,
#        <Axes: title={'center': 'engine_cc'}>,
#        <Axes: title={'center': 'owner_count'}>,
#        <Axes: title={'center': 'price_usd'}>,
#        <Axes: title={'center': 'accidents_reported'}>], dtype=object)

# %%
coll.groupby('Faculty').count()['ID'].plot(kind='bar').scatter(x='Faculty', y='Student Attendance')

# %%
cars.groupby(['brand', 'transmission'])['mileage_kmpl'].count().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='brand,transmission'>

# %%
cars.groupby(['brand', 'transmission']).count()
# Out:
#                          make_year  mileage_kmpl  engine_cc  fuel_type  \
# brand      transmission
# BMW        Automatic           385           385        385        385
#            Manual              636           636        636        636
# Chevrolet  Automatic           410           410        410        410
#            Manual              589           589        589        589
# Ford       Automatic           402           402        402        402
#            Manual              547           547        547        547
# Honda      Automatic           406           406        406        406
#            Manual              597           597        597        597
# Hyundai    Automatic           375           375        375        375
#            Manual              614           614        614        614
# Kia        Automatic           357           357        357        357
#            Manual              598           598        598        598
# ...

# %%
cars.groupby(['brand', 'transmission'])['owner_count'].sum().plot.barh(stacked=True).scatter(x='Transmission', y='Brand')

# %%
cars.groupby(['brand', 'transmission'])['owner_count'].sum().plot(kind='barh', width=0.9).scatter(x='transmission', y='brand')

# %%
cars.groupby(['fuel_type']).count()['color'].plot(kind='bar')
# Out:
# <Axes: xlabel='fuel_type'>

# %%
cars.groupby(['fuel_type']).count()
# Out:
#            make_year  mileage_kmpl  engine_cc  owner_count  price_usd  brand  \
# fuel_type
# Diesel          4058          4058       4058         4058       4058   4058
# Electric         974           974        974          974        974    974
# Petrol          4968          4968       4968         4968       4968   4968
#
#            transmission  color  service_history  accidents_reported  \
# fuel_type
# Diesel             4058   4058             3210                4058
# Electric            974    974              781                 974
# Petrol             4968   4968             3971                4968
#
#            insurance_valid
# fuel_type
# Diesel                4058
# Electric               974
# Petrol                4968

# %%
cars['make_year'].min()
# Out:
# 1995

# %%
cars.groupby(['fuel_type']).count()['make_year'].plot(kind='pie')
# Out:
# <Axes: ylabel='make_year'>

# %%
coll.groupby('Faculty').count()['ID'].plot(kind='pie', fontsize=40, figsize=(50,50))
# Out:
# <Axes: ylabel='ID'>

# %%
cars['make_year'].plot.hist(bins=29, width=0.9)
# Out:
# <Axes: ylabel='Frequency'>

# %%
cars_nums = cars.drop(columns=['transmission', 'service_history', 'insurance_valid', 'color', 'fuel_type'])

# %%
#cars_nums.groupby(['brand']).mean()['mileage_kmpl'].boxplot()
cars_nums[cars_nums['brand'] == 'BMW'].boxplot()
# Out:
# <Axes: >

# %%
cars_nums.groupby('brand').count()
# Out:
#             make_year  mileage_kmpl  engine_cc  owner_count  price_usd  \
# brand
# BMW              1021          1021       1021         1021       1021
# Chevrolet         999           999        999          999        999
# Ford              949           949        949          949        949
# Honda            1003          1003       1003         1003       1003
# Hyundai           989           989        989          989        989
# Kia               955           955        955          955        955
# Nissan           1089          1089       1089         1089       1089
# Tesla            1006          1006       1006         1006       1006
# Toyota            956           956        956          956        956
# Volkswagen       1033          1033       1033         1033       1033
#
#             accidents_reported
# brand
# BMW                       1021
# Chevrolet                  999
# Ford                       949
# Honda                     1003
# ...

# %%
cars_nums[cars_nums['brand'] == 'Chevrolet'].boxplot()
# Out:
# <Axes: >

# %%
cars_nums[cars_nums['brand'] == 'Ford'].boxplot()
# Out:
# <Axes: >

# %%
cars_nums[cars_nums['brand'] == 'Honda'].boxplot()
# Out:
# <Axes: >

# %%
cars_nums[cars_nums['brand'] == 'Hyundai'].boxplot()
# Out:
# <Axes: >

# %%
cars_nums[cars_nums['brand'] == 'Kia'].boxplot(figsize=(10,8))
# Out:
# <Axes: >

# %%
cars_nums.plot.area()
# Out:
# <Axes: >

# %%
print(plt.style.available)
plt.style.use('_classic_test_patch')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
cars.drop_duplicates(inplace=True)

# %%
cars.shape
# Out:
# (10000, 12)

# %%
coll.shape
# Out:
# (2760, 3)

# %%
coll.drop_duplicates(inplace=True)

# %%
coll.shape
# Out:
# (2760, 3)

# %%
gen = ['rock', 'R&B', 'Soundtrack', 'soul', 'R&B', 'pop']
for i in gen:
  print(i)
# Out:
# rock
# R&B
# Soundtrack
# soul
# R&B
# pop

# %%
for i in range(1,12):
  print(i, ' X ', 6, ' = ', i* 6)
# Out:
# 1  X  6  =  6
# 2  X  6  =  12
# 3  X  6  =  18
# 4  X  6  =  24
# 5  X  6  =  30
# 6  X  6  =  36
# 7  X  6  =  42
# 8  X  6  =  48
# 9  X  6  =  54
# 10  X  6  =  60
# 11  X  6  =  66

# %%
for i in range(1,12):
  print(i, ' X ', 7, ' = ', i* 7)
# Out:
# 1  X  7  =  7
# 2  X  7  =  14
# 3  X  7  =  21
# 4  X  7  =  28
# 5  X  7  =  35
# 6  X  7  =  42
# 7  X  7  =  49
# 8  X  7  =  56
# 9  X  7  =  63
# 10  X  7  =  70
# 11  X  7  =  77

# %%
animals = ['deer', 'lion', 'giraffe', 'gorilla', 'parrots', 'crocodile', 'swan']
for i in animals:
  if (len(i) >= 7):
    print (i)
# Out:
# giraffe
# gorilla
# parrots
# crocodile

# %%
def f1(a,b):
  def f2(c):
    return a + b + c
  return a + b
